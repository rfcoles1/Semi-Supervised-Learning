# %%
from plot_results import *
from datasets import *
from augment import *

# %%
Data = Loader(0.2, 'load_z')

x_train, y_train = Data.get_train(0.25)
x_test,y_test = Data.get_test()

np.shape(x_train)
# Out:
# Could not generate galaxy data
# 45.00% of the data has been used
# (2499, 64, 64, 5)

# %%
plt.imshow(x_train[1,:,:,2])

# %%
a = cutimgs(x_train)
print(np.shape(a))
plt.imshow(a[1,:,:,2])
# Out:
# (2499, 32, 32, 5)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['rotate'], M=[[0,360]])
show_aug(x_train[1], Aug, channel=2, resize=False,size=32)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['rotate'], M=[[0,360]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['translateX'], M=[[0,16]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['shear'], M=[[0.3,0.4]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['cutout'], M=[[4,8]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['filter'], M=[[0,0.5]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
#multiplies each channel by max value in the channel multiplied by M
Aug = Augmenter(imgsize=64, N=1, transforms=['flatscale'], M=[[0,0.1]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
#adds to each channel by random normal noise 
#the sigma for each channel max value in the channel multiplied by M
Aug = Augmenter(imgsize=64, N=1, transforms=['noisescale'], M=[[0,0.1]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
#adds to each channel by random normal noise 
#the sigma for each channel max value in the channel multiplied by M
Aug = Augmenter(imgsize=64, N=1, transforms=['noise'], M=[[0,0.1]])
show_aug(x_train[1], Aug, channel=2, resize=True,size=32)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['removecolour'], M=[[0,5]])
show_aug_all_channels(x_train[1], Aug)

# %%
Aug = Augmenter(imgsize=64, N=1, transforms=['colourjitter'], M=[[0,5]])
show_aug_all_channels(x_train[1], Aug)
